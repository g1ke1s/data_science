# %%
import pandas as pd

# %%
titanic = pd.read_csv(r"C:\Users\g1kss\Downloads\StudentsPerformance.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3712\3948888460.py in <module>
# ----> 1 titanic = pd.read_csv(r"C:\Users\g1kss\Downloads\StudentsPerformance.csv")
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
titanic
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
import pandas as pd

# %%
pd = pd.read_csv(r"C:\Users\g1kss\Downloads\StudentsPerformance (1).csv")

# %%
pd.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
standard = pd.loc[pd.lunch == 'standard']
s1 = pd.groupby(['lunch'], as_index=False). \
agg({'math score': ['mean', 'std', 'count'], 'reading score': ['mean', 'std', 'count'], 'writing score': ['mean', 'std', 'count']})

# %%
s1
# Out:
#           lunch math score                  reading score                   \
#                       mean        std count          mean        std count
# 0  free/reduced  58.921127  15.159956   355     64.653521  14.895339   355
# 1      standard  70.034109  13.653501   645     71.654264  13.830602   645
#
#   writing score
#            mean        std count
# 0     63.022535  15.433823   355
# 1     70.823256  14.339487   645

# %%
pd.filter(like='score')
# Out:
#      math score  reading score  writing score
# 0            72             72             74
# 1            69             90             88
# 2            90             95             93
# 3            47             57             44
# 4            76             78             75
# ..          ...            ...            ...
# 995          88             99             95
# 996          62             55             55
# 997          59             71             65
# 998          68             78             77
# 999          77             86             86
#
# [1000 rows x 3 columns]

# %%
import pandas as pd

# %%
dota = pd.read_csv(r"C:\Users\g1kss\Downloads\dota_hero_stats.csv")

# %%
dota.groupby('legs').agg({'legs': 'count'})
# Out:
#       legs
# legs
# 0       11
# 2       95
# 4        7
# 6        3
# 8        1

# %%
dota.value_counts('legs')
# Out:
# legs
# 2    95
# 0    11
# 4     7
# 6     3
# 8     1
# dtype: int64

# %%
standard
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16716\4214111933.py in <module>
# ----> 1 standard
#
# NameError: name 'standard' is not defined

# %%
salary = pd.read_csv(r"C:\Users\g1kss\Downloads\accountancy.csv")

# %%
salary.groupby(['Executor', 'Type']).agg({'Salary': 'mean'})
# Out:
#                    Salary
# Executor Type
# Loopa    A      58.000000
#          B     145.166667
#          C     154.333333
#          D     137.714286
#          E     164.000000
#          F     238.000000
# Pupa     A     160.833333
#          B      77.000000
#          C      74.500000
#          D     146.500000
#          E     131.200000
#          F     136.250000

# %%
salary
# Out:
#     Unnamed: 0 Executor Type  Salary
# 0            0     Pupa    D      63
# 1            1     Pupa    A     158
# 2            2     Pupa    D     194
# 3            3     Pupa    E     109
# 4            4    Loopa    E     184
# 5            5    Loopa    F     232
# 6            6    Loopa    B     249
# 7            7     Pupa    F     195
# 8            8     Pupa    A     115
# 9            9     Pupa    E      65
# 10          10    Loopa    C     145
# 11          11    Loopa    D     149
# 12          12    Loopa    B      50
# 13          13     Pupa    A     217
# 14          14    Loopa    D     110
# 15          15     Pupa    F      62
# 16          16     Pupa    A      55
# 17          17    Loopa    B     190
# 18          18    Loopa    E      83
# 19          19     Pupa    A     234
# 20          20    Loopa    E     156
# 21          21    Loopa    E     219
# 22          22     Pupa    C      55
# 23          23     Pupa    D     144
# ...

# %%
dota.groupby(['attack_type', 'primary_attr']) \
 .count()
# Out:
#                           Unnamed: 0  id  legs  localized_name  name  roles
# attack_type primary_attr
# Melee       agi                   19  19    19              19    19     19
#             int                    2   2     2               2     2      2
#             str                   35  35    35              35    35     35
# Ranged      agi                   18  18    18              18    18     18
#             int                   40  40    40              40    40     40
#             str                    3   3     3               3     3      3

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16716\26193472.py in <module>
# ----> 1 pd
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
titanic = pd.read_csv(r"C:\Users\g1kss\Downloads\StudentsPerformance.csv")

# %%
titanic = titanic.rename(columns={'math score': 'math_score', 'reading score': 'reading_score', '	writing score': 'writing_score'})

# %%
titanic.math_score.hist()
# Out:
# <AxesSubplot:>

# %%
titanic.plot.scatter(x='math_score', y = 'reading_score')
# Out:
# <AxesSubplot:xlabel='math_score', ylabel='reading_score'>

# %%
ax = sns.lmplot(x='math_score', y = 'reading_score',hue='gender', data=titanic, fit_reg=False)
ax.set_xlabels('Math score')
ax.set_ylabels('Reading score')

# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\g1kss\Downloads\genome_matrix.csv", index_col=0)

# %%
sns.heatmap(data=df, cmap="viridis")
sns.xaxis.set_ticks_position('top')
sns.xaxis.set_tick_params(rotation=90)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14308\1468512658.py in <module>
#       1 sns.heatmap(data=df, cmap="viridis")
# ----> 2 sns.xaxis.set_ticks_position('top')
#       3 sns.xaxis.set_tick_params(rotation=90)
#
# AttributeError: module 'seaborn' has no attribute 'xaxis'

# %%
plt.plot(df.index, df.species0)

# %%
df.plot(kind='line')
# Out:
# <AxesSubplot:>

# %%
sns.lineplot(x=df.index, y=df.income)
# Out:
# <AxesSubplot:ylabel='income'>

# %%
sns.lineplot(data=df)
# Out:
# <AxesSubplot:>

# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dota = pd.read_csv(r"C:\Users\g1kss\Downloads\dota_hero_stats (1).csv")

# %%
dota.groupby('localized_name').agg({'roles': '})
# Out:
#   File "C:\Users\g1kss\AppData\Local\Temp\ipykernel_14308\3019010559.py", line 1
#     dota.groupby('localized_name').agg({'roles': '})
#                                                     ^
# SyntaxError: EOL while scanning string literal

# %% [raw]
# sns.histplot(data=dota, x='localized_name', y='roles')

# %%
dota
# Out:
#      Unnamed: 0 attack_type   id  legs  localized_name  \
# 0             0       Melee    1     2       Anti-Mage
# 1             1       Melee    2     2             Axe
# 2             2      Ranged    3     4            Bane
# 3             3       Melee    4     2     Bloodseeker
# 4             4      Ranged    5     2  Crystal Maiden
# ..          ...         ...  ...   ...             ...
# 112         112       Melee  114     2     Monkey King
# 113         113      Ranged  119     2     Dark Willow
# 114         114       Melee  120     2       Pangolier
# 115         115      Ranged  121     2      Grimstroke
# 116         116       Melee  129     2            Mars
#
#                              name primary_attr  \
# 0          npc_dota_hero_antimage          agi
# 1               npc_dota_hero_axe          str
# 2              npc_dota_hero_bane          int
# 3       npc_dota_hero_bloodseeker          agi
# 4    npc_dota_hero_crystal_maiden          int
# ...

# %%
x = sns.histplot(data=dota, x='localized_name', y='roles')

# %%
dota.plot.hist(x = )
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
dota.roles.mode()
# Out:
# 0    ['Carry', 'Disabler', 'Initiator', 'Durable', ...
# 1                                  ['Carry', 'Escape']
# 2                     ['Support', 'Disabler', 'Nuker']
# 3           ['Support', 'Nuker', 'Disabler', 'Escape']
# 4                     ['Support', 'Nuker', 'Disabler']
# Name: roles, dtype: object
