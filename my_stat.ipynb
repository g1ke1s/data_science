# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv(r"C:\Users\spark lab\Desktop\my_stat_1.csv")

# %%
data
# Out:
#    session_value  time group  n_users
# 0            0.0    12     B        9
# 1            NaN    11     A       -1
# 2            1.0     8     A        1
# 3            2.0     9     B        3
# 4            2.0    10     B        9
# 5            3.0     8     A        8
# 6            NaN    11     B        5
# 7            0.0     9     A        4
# 8            0.0     8     B      -11
# 9            0.0     9     A      -20

# %%
data['session_value'].fillna(0, inplace=True)

# %%
data
# Out:
#    session_value  time group  n_users
# 0            0.0    12     B        9
# 1            0.0    11     A       -1
# 2            1.0     8     A        1
# 3            2.0     9     B        3
# 4            2.0    10     B        9
# 5            3.0     8     A        8
# 6            0.0    11     B        5
# 7            0.0     9     A        4
# 8            0.0     8     B      -11
# 9            0.0     9     A      -20

# %%
n_users_nonneg = data.query('n_users >= 0')

# %%
n_users_nonneg
# Out:
#    session_value  time group  n_users
# 0            0.0    12     B        9
# 2            1.0     8     A        1
# 3            2.0     9     B        3
# 4            2.0    10     B        9
# 5            3.0     8     A        8
# 6            0.0    11     B        5
# 7            0.0     9     A        4

# %%
n_users_nonneg['n_users'].median()
# Out:
# 5.0

# %%
data1 = pd.read_csv(r"https://stepik.org/media/attachments/course/4852/my_stat.csv")
data1

# %%
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv(r"https://stepik.org/media/attachments/course/4852/iris.csv")
df
# Out:
#      Unnamed: 0  sepal length  sepal width  petal length  petal width  species
# 0             0           5.1          3.5           1.4          0.2        0
# 1             1           4.9          3.0           1.4          0.2        0
# 2             2           4.7          3.2           1.3          0.2        0
# 3             3           4.6          3.1           1.5          0.2        0
# 4             4           5.0          3.6           1.4          0.2        0
# ..          ...           ...          ...           ...          ...      ...
# 145         145           6.7          3.0           5.2          2.3        2
# 146         146           6.3          2.5           5.0          1.9        2
# 147         147           6.5          3.0           5.2          2.0        2
# 148         148           6.2          3.4           5.4          2.3        2
# 149         149           5.9          3.0           5.1          1.8        2
#
# [150 rows x 6 columns]

# %%
df.plot.scatter(x='petal width', y='petal length')
# Out:
# <Axes: xlabel='petal width', ylabel='petal length'>

# %%
sns.kdeplot(data=df, x="petal length")
# Out:
# <Axes: xlabel='petal length', ylabel='Density'>

# %%
sns.distplot(df)
# Out:
# C:\Users\spark lab\AppData\Local\Temp\ipykernel_2020\107776459.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df)
# <Axes: ylabel='Density'>

# %%
sns.kdeplot(data=df, x="petal width")
# Out:
# <Axes: xlabel='petal width', ylabel='Density'>

# %%
sns.kdeplot(data=df, x="sepal width")
# Out:
# <Axes: xlabel='sepal width', ylabel='Density'>

# %%
sns.kdeplot(data=df, x="sepal length")
# Out:
# <Axes: xlabel='sepal length', ylabel='Density'>

# %%
sns.pairplot(df,  vars=df.columns[:-1], diag_kind='kde')

# %%
sns.violinplot(y=df["petal length"])
# Out:
# <Axes: ylabel='petal length'>

# %%
sns.pairplot(df)

# %%
df.corr()
# Out:
#               Unnamed: 0  sepal length  sepal width  petal length  \
# Unnamed: 0      1.000000      0.716676    -0.397729      0.882747
# sepal length    0.716676      1.000000    -0.109369      0.871754
# sepal width    -0.397729     -0.109369     1.000000     -0.420516
# petal length    0.882747      0.871754    -0.420516      1.000000
# petal width     0.899759      0.817954    -0.356544      0.962757
# species         0.942830      0.782561    -0.419446      0.949043
#
#               petal width   species
# Unnamed: 0       0.899759  0.942830
# sepal length     0.817954  0.782561
# sepal width     -0.356544 -0.419446
# petal length     0.962757  0.949043
# petal width      1.000000  0.956464
# species          0.956464  1.000000

# %%
events = pd.read_csv(r"C:\Users\spark lab\Desktop\event_data_train.csv")
events.user_id.value_counts()
# Out:
# 20907    33043
# 10794    16436
# 25279    10179
# 1046      9095
# 3572      7905
#          ...
# 14865        2
# 3395         2
# 26502        1
# 8773         1
# 11437        1
# Name: user_id, Length: 19234, dtype: int64

# %%
events[events['user_id'] == 20907].count()
# Out:
# step_id      33043
# timestamp    33043
# action       33043
# user_id      33043
# dtype: int64

# %%
submissions = pd.read_csv(r"C:\Users\spark lab\Desktop\submissions_data_train.csv")
submissions
# Out:
#         step_id   timestamp submission_status  user_id
# 0         31971  1434349275           correct    15853
# 1         31972  1434348300           correct    15853
# 2         31972  1478852149             wrong    15853
# 3         31972  1478852164           correct    15853
# 4         31976  1434348123             wrong    15853
# ...         ...         ...               ...      ...
# 509099   120745  1501946959             wrong     2615
# 509100   120745  1503059927           correct    13177
# 509101   120745  1506348153             wrong    15253
# 509102   120745  1523035316             wrong     1424
# 509103   120745  1523382825             wrong     9422
#
# [509104 rows x 4 columns]

# %%
submissions.user_id.value_counts()
# Out:
# 12265    1051
# 3643      948
# 1046      934
# 14454     920
# 643       888
#          ...
# 17245       1
# 24737       1
# 477         1
# 4730        1
# 9422        1
# Name: user_id, Length: 9940, dtype: int64
